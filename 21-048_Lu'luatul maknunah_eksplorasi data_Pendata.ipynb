# %% [markdown]
# Nama : Lu'luatul Maknunah
# NIM  : 210411100048

# %% [markdown]
# Menampilkan data dari database postgres menggunakan python

# %%
#koneksi dengan database postgres dan menmpilkan data
from sqlalchemy import create_engine
import pandas as pd
import pandas.io.sql as sqlio
import psycopg2 as ps
engine = create_engine('postgresql://postgres:luna@localhost:5432/Luluatulm')
sql = """select * from public.eda_iris"""
df = sqlio.read_sql_query(sql,engine)
print('Data keseluruhan')
df
# Out:
# Data keseluruhan
#         id  sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm  \
# 0      1.0            5.1           3.5            1.4           0.2
# 1      2.0            4.9           3.0            1.4           0.2
# 2      3.0            4.7           3.2            1.3           0.2
# 3      4.0            4.6           3.1            1.5           0.2
# 4      5.0            5.0           3.6            1.4           0.2
# ..     ...            ...           ...            ...           ...
# 145  146.0            6.7           3.0            5.2           2.3
# 146  147.0            6.3           2.5            5.0           1.9
# 147  148.0            6.5           3.0            5.2           2.0
# 148  149.0            6.2           3.4            5.4           2.3
# 149  150.0            5.9           3.0            5.1           1.8
#
#             species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# ...

# %%
#menmapilkan data berdasarkan jenis species
sqls = """select * from public.eda_iris where species='Iris-setosa'"""
dfs = sqlio.read_sql_query(sqls,engine)
print('Data SPECIES SETOSA')
dfs
# Out:
# Data SPECIES SETOSA
#       id  sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm  \
# 0    1.0            5.1           3.5            1.4           0.2
# 1    2.0            4.9           3.0            1.4           0.2
# 2    3.0            4.7           3.2            1.3           0.2
# 3    4.0            4.6           3.1            1.5           0.2
# 4    5.0            5.0           3.6            1.4           0.2
# 5    6.0            5.4           3.9            1.7           0.4
# 6    7.0            4.6           3.4            1.4           0.3
# 7    8.0            5.0           3.4            1.5           0.2
# 8    9.0            4.4           2.9            1.4           0.2
# 9   10.0            4.9           3.1            1.5           0.1
# 10  11.0            5.4           3.7            1.5           0.2
# 11  12.0            4.8           3.4            1.6           0.2
# 12  13.0            4.8           3.0            1.4           0.1
# ...

# %%
sqlv = """select * from public.eda_iris where species='Iris-versicolor'"""
dfv = sqlio.read_sql_query(sqlv,engine)
print('Data SPECIES Versi color')
dfv
# Out:
# Data SPECIES Versi color
#        id  sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm  \
# 0    51.0            7.0           3.2            4.7           1.4
# 1    52.0            6.4           3.2            4.5           1.5
# 2    53.0            6.9           3.1            4.9           1.5
# 3    54.0            5.5           2.3            4.0           1.3
# 4    55.0            6.5           2.8            4.6           1.5
# 5    56.0            5.7           2.8            4.5           1.3
# 6    57.0            6.3           3.3            4.7           1.6
# 7    58.0            4.9           2.4            3.3           1.0
# 8    59.0            6.6           2.9            4.6           1.3
# 9    60.0            5.2           2.7            3.9           1.4
# 10   61.0            5.0           2.0            3.5           1.0
# 11   62.0            5.9           3.0            4.2           1.5
# ...

# %%
sqlvir = """select * from public.eda_iris where species='Iris-virginica'"""
dfvir = sqlio.read_sql_query(sqlvir,engine)
print('Data SPECIES Versi color')
dfvir
# Out:
# Data SPECIES Versi color
#        id  sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm  \
# 0   101.0            6.3           3.3            6.0           2.5
# 1   102.0            5.8           2.7            5.1           1.9
# 2   103.0            7.1           3.0            5.9           2.1
# 3   104.0            6.3           2.9            5.6           1.8
# 4   105.0            6.5           3.0            5.8           2.2
# 5   106.0            7.6           3.0            6.6           2.1
# 6   107.0            4.9           2.5            4.5           1.7
# 7   108.0            7.3           2.9            6.3           1.8
# 8   109.0            6.7           2.5            5.8           1.8
# 9   110.0            7.2           3.6            6.1           2.5
# 10  111.0            6.5           3.2            5.1           2.0
# 11  112.0            6.4           2.7            5.3           1.9
# ...

# %% [markdown]
# Iris dataset terdiri dari 3 spesier yaitu iris setosa, iris versicolor, iris virginica dimana setiap spesiesnya didapatkan 50 sampel dengan kriteria dari masing-masing sampel antara lain panjang,lebar sepal, dan kelopak dalam sentimeter.
# iris data memiliki kolom sepal length untuk panjang sepal, sepal width untuk lebar sepal, petal length untuk panjang kelopak, petal width untuk lebar kelopak.
